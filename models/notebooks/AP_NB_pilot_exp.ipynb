# %% [markdown]
# # Dedicated to finding:
# ## - somewhat optimal hyperparameters in the Apriori Naive Bayes model

# %% [markdown]
# ---
#
# ## importing modules

# %%
# importing modules

import pandas as pd
import numpy as np
import math
from sklearn.feature_extraction.text import CountVectorizer
from mlxtend.frequent_patterns import apriori
from sklearn.model_selection import RepeatedKFold, KFold, train_test_split
from sklearn.metrics import f1_score, accuracy_score
import time
from mlxtend.preprocessing import TransactionEncoder

from ast import literal_eval
from tqdm.notebook import tqdm
import mmh3
from itertools import product


seed = 42

# %% [markdown]
# ---
#
# ## Defining the model

# %%
# create shingle function
def shingles(term_list:list,q:int):
    string = ' '.join(term_list)
    output = set()
    for i in range(len(string)+1):
        if i < q:
            pass
        else:
            output.add(''.join(string[i-q:i]))
    return list(output)


# OLD
def apriori_for_binary(df, labels, minimum_support, look_up):
    word_freq_dict = {}
    # CHOOSE support and confidence
    # minimum_support = [0.005, 0.03] # for 'ham' and 'spam' respectivly
    # looping labels
    for idx, y in enumerate(labels):
        # filtering
        filtered_df = df[df.label == y]
        # generating corpus for vectorizer
        corpus = []
        for row in filtered_df[look_up]:
            corpus.append(' '.join(row))
        # vectorizing words
        vectorizer = CountVectorizer()
        X = vectorizer.fit_transform(corpus)
        column_values = vectorizer.get_feature_names_out()
        # generating dataframe
        transformed_df = pd.DataFrame(data=X.toarray(), columns=column_values)
        # performing a-priori
        word_freqs = apriori(transformed_df.astype(bool),
                             min_support=minimum_support[idx],
                             use_colnames=True)
        word_freqs.itemsets = word_freqs.itemsets.apply(lambda x: set(x)).astype("unicode").apply(literal_eval)

        word_freq_dict[y] = word_freqs
    # word frequency dictionaries based on apriori for the two labels
    return word_freq_dict


def get_freq_itemset(data, labels, look_up, num_itemsets):
    freq_itemsets_dict = {}
    for idx, label in enumerate(labels):
        support=0.1
        itemsets=[]
        while len(itemsets) <= num_itemsets[idx]:
            filtered_data = data[data.label == label]
            look_up_data = list(filtered_data[look_up].values)
            te = TransactionEncoder()
            te_ary = te.fit(look_up_data).transform(look_up_data)
            df = pd.DataFrame(te_ary, columns=te.columns_)
            itemsets = apriori(df, min_support=support, use_colnames=True)
            support -= support/20
        # finding top supported
        formatting = itemsets.sort_values(by='support', ascending=False).iloc[:num_itemsets[idx]].reset_index()
        # todo: normalizing
        #formatting.support = formatting.support/formatting.support.sum()
        freq_itemsets_dict[label] = formatting

    return freq_itemsets_dict


# using naive bayes
def NB_classify(x, freq_itemsets_dict, labels, priors):
    # unique
    combined = set(list(freq_itemsets_dict[labels[0]].itemsets) + list(freq_itemsets_dict[labels[1]].itemsets))
    # Laplace estimator in bayes, to avoid the log(0)
    len_vocabulary = len(combined)

    # making loop general for both labels
    denominators = []
    # posterior probabilities
    prob = []
    # to avoid log 0
    min_value = []
    # initialize
    for idx, label in enumerate(labels):
        # data is not normalized hence normalizing coefficient given supports for current label
        denominators.append(freq_itemsets_dict[label].support.sum())
        # prior is added to probability
        prob.append(np.log(priors[label]))
        min_value.append(min(freq_itemsets_dict[label].support))

    # looping each wordset of combination
    for word_set in combined:
        # if current word set is a subset of x
        if set(word_set).issubset(x):
            # if word set in itemsets for this label
            # originally 1 as prob should be added even if not represented
            count = count_occurences(word_set, x) 
            in_or_not = [0, 0]
            support = [0, 0]
            # so it is in combined, but maybe not in both freq itemsets
            if word_set in list(freq_itemsets_dict[labels[0]].itemsets):
                in_or_not[0] = 1
                support[0] = float(
                    (freq_itemsets_dict[labels[0]].loc[freq_itemsets_dict[labels[0]]['itemsets'] == word_set]).support)
            # if this label, notice, can be in both
            if word_set in list(freq_itemsets_dict[labels[1]].itemsets):
                in_or_not[1] = 1
                support[1] = float(
                    (freq_itemsets_dict[labels[1]].loc[freq_itemsets_dict[labels[1]]['itemsets'] == word_set]).support)
            # print(support)
            # calculating posterior
            for idx, label in enumerate(labels):
                #prob[idx] += np.log(((in_or_not[idx] * support[idx] + 1) / (denominators[idx] + len_vocabulary)))*count
                #prob[idx] += np.log((in_or_not[idx] * support[idx] + 1/len_vocabulary) * count
                prob[idx] += np.log( in_or_not[idx]*support[idx] + min_value[idx]/2) * count
                # with denominator
                #prob[idx] += np.log( (in_or_not[idx]*support[idx])/denominators[idx] + min_value[idx]/2) * count

    prediction = labels[np.argmax(prob)]
    # predicted label
    return prediction


def count_occurences(word_set, x):
    if len(word_set) == 1:
        return x.count(list(word_set)[0])
    else:
        diff_counts = []
        for string in list(word_set):
            diff_counts.append(x.count(string))
        # returning minimum value
        return min(diff_counts)


# Complete algorithm

def apriori_NB(train, test, method, hparams):

    if method == 'terms':
        look_up = 'tokens'
    elif method == 'shingles':
        look_up = 'shingles'
    else:
        raise NotImplementedError


    num_itemsets = list(hparams)

    # hyperparameters
    labels = list(np.unique(train.label))  # currently repeated

    # getting frequent itemsets
    freq_itemsets_dict = get_freq_itemset(train, labels, look_up, num_itemsets)
    # word_freq_dict =  apriori_for_binary(train, labels, minimum_support, look_up)

    # calculating prior for NB
    priors = {}
    for label in labels:
        # prior is based on the balance of labels in dataset
        prior = sum(train.label == label) / len(train)
        priors[label] = prior

    # classifying using the naive bayes
    y_test = []
    y_pred = []

    for idx, x in test.iterrows():
        # by x.tokens we remove the 'label' data
        # classifying
        pred = NB_classify(x[look_up], freq_itemsets_dict, labels, priors)
        y_pred.append(pred)
        y_test.append(x.label)

    f1 = f1_score(y_test, y_pred, pos_label='spam')
    acc = accuracy_score(y_test, y_pred)

    # TODO: f1_score
    print(f'Performance: f1={np.round(f1, 5)}  |  acc={np.round(acc, 5)}')
    # check size of sets based om support values

    print(f'   sets={num_itemsets}: [{len(freq_itemsets_dict[labels[0]])},{len(freq_itemsets_dict[labels[1]])}]\n')

    return (f1, acc)

# %% [markdown]
# ---
#
# # Pilot for the SMS dataset

# %%
# loading dataset
data = pd.read_csv(f'../data/clean_spam.csv')
data.tokens = data.tokens.apply(literal_eval)

# splitting dataset
train, test = train_test_split(data, test_size=0.33, random_state=0)
train.reset_index(inplace=True);
test.reset_index(inplace=True);

# %% [markdown]
# ### Shingles

# %%
itemsets_ham = list(np.linspace(100,2000, 20).astype(int))

itemsets_spam = list(np.linspace(100,2000, 20).astype(int))

#q_shingles = np.arange(2,9)

# list of all hparams
hparams = [itemsets_ham, itemsets_spam]#, list(q_shingles)]
# running combination of hparams
combinations = list(product(*hparams))


q=5
method = 'shingles'


df_shingles = {i: [shingles(train['tokens'][i], q=q)] for i in list(train.index)}
train['shingles'] = pd.DataFrame.from_dict(df_shingles, orient='index')
df_shingles = {i: [shingles(test['tokens'][i], q=q)] for i in list(test.index)}
test['shingles'] = pd.DataFrame.from_dict(df_shingles, orient='index')
#train.shingles = train.shingles.apply(literal_eval)

# %%
len(combinations)
# Out:
# 16

# %%
for hparam in tqdm(combinations):
    out = apriori_NB(train=train, test=test, method=method, hparams=hparam)
    #f1, acc = out
# Out:
#   0%|          | 0/400 [00:00<?, ?it/s]
# Performance: f1=0.66667  |  acc=0.87058
#    sets=[100, 100]: [100,100]
#
# Performance: f1=0.64411  |  acc=0.85699
#    sets=[100, 200]: [100,200]
#
# Performance: f1=0.64578  |  acc=0.85862
#    sets=[100, 300]: [100,300]
#
# Performance: f1=0.6539  |  acc=0.86243
#    sets=[100, 400]: [100,400]
#
# Performance: f1=0.64096  |  acc=0.85318
#    sets=[100, 500]: [100,500]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/p0/2qnwrmjn7yd0ks7pnlb3d7mc0000gn/T/ipykernel_55088/1390998523.py in <module>
#       1 for hparam in tqdm(combinations):
# ----> 2     out = apriori_NB(train=train, test=test, method=method, hparams=hparam)
#       3     #f1, acc = out
#       4
#
# /var/folders/p0/2qnwrmjn7yd0ks7pnlb3d7mc0000gn/T/ipykernel_55088/791292469.py in apriori_NB(train, test, method, hparams)
#     146
#     147     # getting frequent itemsets
# --> 148     freq_itemsets_dict = get_freq_itemset(train, labels, look_up, num_itemsets)
#     149     # word_freq_dict =  apriori_for_binary(train, labels, minimum_support, look_up)
#     150
#
# /var/folders/p0/2qnwrmjn7yd0ks7pnlb3d7mc0000gn/T/ipykernel_55088/791292469.py in get_freq_itemset(data, labels, look_up, num_itemsets)
#      52             te_ary = te.fit(look_up_data).transform(look_up_data)
#      53             df = pd.DataFrame(te_ary, columns=te.columns_)
# ---> 54             itemsets = apriori(df, min_support=support, use_colnames=True)
#      55             support -= support/20
#      56         # finding top supported
#
# ~/opt/anaconda3/envs/comsocsci2022/lib/python3.8/site-packages/mlxtend/frequent_patterns/apriori.py in apriori(df, min_support, use_colnames, max_len, verbose, low_memory)
#     324         itemsets = pd.Series([frozenset(i) for i in itemset_dict[k]], dtype="object")
#     325
# --> 326         res = pd.concat((support, itemsets), axis=1)
#     327         all_res.append(res)
#     328
#
# ~/opt/anaconda3/envs/comsocsci2022/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/envs/comsocsci2022/lib/python3.8/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     305     )
#     306
# --> 307     return op.get_result()
#     308
#     309
#
# ~/opt/anaconda3/envs/comsocsci2022/lib/python3.8/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     506
#     507                 index, columns = self.new_axes
# --> 508                 df = cons(data, index=index, copy=self.copy)
#     509                 df.columns = columns
#     510                 return df.__finalize__(self, method="concat")
#
# ~/opt/anaconda3/envs/comsocsci2022/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ~/opt/anaconda3/envs/comsocsci2022/lib/python3.8/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     462         # TODO: can we get rid of the dt64tz special case above?
#     463
# --> 464     return arrays_to_mgr(
#     465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#
# ~/opt/anaconda3/envs/comsocsci2022/lib/python3.8/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     122
#     123         # don't force copy because getting jammed in an ndarray anyway
# --> 124         arrays = _homogenize(arrays, index, dtype)
#     125
#     126     else:
#
# ~/opt/anaconda3/envs/comsocsci2022/lib/python3.8/site-packages/pandas/core/internals/construction.py in _homogenize(data, index, dtype)
#     569                 # Forces alignment. No need to copy data since we
#     570                 # are putting it into an ndarray later
# --> 571                 val = val.reindex(index, copy=False)
#     572
#     573             val = val._values
#
# ~/opt/anaconda3/envs/comsocsci2022/lib/python3.8/site-packages/pandas/core/series.py in reindex(self, index, **kwargs)
#    4578     )
#    4579     def reindex(self, index=None, **kwargs):
# -> 4580         return super().reindex(index=index, **kwargs)
#    4581
#    4582     @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#
# ~/opt/anaconda3/envs/comsocsci2022/lib/python3.8/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    4802         # if all axes that are requested to reindex are equal, then only copy
#    4803         # if indicated must have index names equal here as well as values
# -> 4804         if all(
#    4805             self._get_axis(axis).identical(ax)
#    4806             for axis, ax in axes.items()
#
# ~/opt/anaconda3/envs/comsocsci2022/lib/python3.8/site-packages/pandas/core/generic.py in <genexpr>(.0)
#    4803         # if indicated must have index names equal here as well as values
#    4804         if all(
# -> 4805             self._get_axis(axis).identical(ax)
#    4806             for axis, ax in axes.items()
#    4807             if ax is not None
#
# ~/opt/anaconda3/envs/comsocsci2022/lib/python3.8/site-packages/pandas/core/indexes/base.py in identical(self, other)
#    4805         return array_equivalent(self._values, other._values)
#    4806
# -> 4807     @final
#    4808     def identical(self, other) -> bool:
#    4809         """
#
# KeyboardInterrupt:

# %%
# testing 
start_time = time.time()
out = apriori_NB(train=train, test=test, method=method, hparams=(2000, 600))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/p0/2qnwrmjn7yd0ks7pnlb3d7mc0000gn/T/ipykernel_49617/580427654.py in <module>
#       1 # testing low min support, more itemsets
#       2 start_time = time.time()
# ----> 3 out = apriori_NB(train=train, test=test, method=method, hparams=(0.007, 0.035))
#       4 print("--- %s seconds ---" % (time.time() - start_time))
#
# /var/folders/p0/2qnwrmjn7yd0ks7pnlb3d7mc0000gn/T/ipykernel_49617/398796984.py in apriori_NB(train, test, method, hparams)
#     135         # by x.tokens we remove the 'label' data
#     136         # classifying
# --> 137         pred = NB_classify(x[look_up], freq_itemsets_dict, labels, priors)
#     138         y_pred.append(pred)
#     139         y_test.append(x.label)
#
# /var/folders/p0/2qnwrmjn7yd0ks7pnlb3d7mc0000gn/T/ipykernel_49617/398796984.py in NB_classify(x, freq_itemsets_dict, labels, priors)
#      76                 count[0] = count_occurences(word_set, x)
#      77             # if this label, notice, can be in both
# ---> 78             if word_set in list(freq_itemsets_dict[labels[1]].itemsets):
#      79                 in_or_not[1] = 1
#      80                 support[1] = float((freq_itemsets_dict[labels[1]].loc[freq_itemsets_dict[labels[1]]['itemsets'] == word_set]).support)
#
# KeyboardInterrupt:

# %% [markdown]
# Based on til pilot run, is seems like...

# %% [markdown]
# ### Terms

# %%
itemsets_ham = list(np.linspace(100,1000, 10).astype(int))

itemsets_spam = list(np.linspace(100,1000, 10).astype(int))

#q_shingles = np.arange(2,9)

# list of all hparams
hparams = [itemsets_ham, itemsets_spam]#, list(q_shingles)]
# running combination of hparams
combinations = list(product(*hparams))


method = 'terms'

# %%
np.linspace(100,1000, 10)
# Out:
# array([ 100.,  200.,  300.,  400.,  500.,  600.,  700.,  800.,  900.,
#        1000.])

# %%
len(combinations)
# Out:
# 9

# %%
combinations
# Out:
# [(100.0, 100.0),
#  (100.0, 200.0),
#  (100.0, 300.0),
#  (100.0, 400.0),
#  (100.0, 500.0),
#  (100.0, 600.0),
#  (100.0, 700.0),
#  (100.0, 800.0),
#  (100.0, 900.0),
#  (100.0, 1000.0),
#  (200.0, 100.0),
#  (200.0, 200.0),
#  (200.0, 300.0),
#  (200.0, 400.0),
#  (200.0, 500.0),
#  (200.0, 600.0),
#  (200.0, 700.0),
#  (200.0, 800.0),
#  (200.0, 900.0),
#  (200.0, 1000.0),
#  (300.0, 100.0),
#  (300.0, 200.0),
#  (300.0, 300.0),
#  (300.0, 400.0),
#  (300.0, 500.0),
#  (300.0, 600.0),
#  (300.0, 700.0),
#  (300.0, 800.0),
#  (300.0, 900.0),
#  (300.0, 1000.0),
#  (400.0, 100.0),
#  (400.0, 200.0),
#  (400.0, 300.0),
#  (400.0, 400.0),
#  (400.0, 500.0),
#  (400.0, 600.0),
#  (400.0, 700.0),
#  (400.0, 800.0),
#  (400.0, 900.0),
#  (400.0, 1000.0),
#  (500.0, 100.0),
#  (500.0, 200.0),
#  (500.0, 300.0),
#  (500.0, 400.0),
#  (500.0, 500.0),
#  (500.0, 600.0),
#  (500.0, 700.0),
#  (500.0, 800.0),
#  (500.0, 900.0),
#  (500.0, 1000.0),
#  (600.0, 100.0),
#  (600.0, 200.0),
#  (600.0, 300.0),
#  (600.0, 400.0),
#  (600.0, 500.0),
#  (600.0, 600.0),
#  (600.0, 700.0),
#  (600.0, 800.0),
#  (600.0, 900.0),
#  (600.0, 1000.0),
#  (700.0, 100.0),
#  (700.0, 200.0),
#  (700.0, 300.0),
#  (700.0, 400.0),
#  (700.0, 500.0),
#  (700.0, 600.0),
#  (700.0, 700.0),
#  (700.0, 800.0),
#  (700.0, 900.0),
#  (700.0, 1000.0),
#  (800.0, 100.0),
#  (800.0, 200.0),
#  (800.0, 300.0),
#  (800.0, 400.0),
#  (800.0, 500.0),
#  (800.0, 600.0),
#  (800.0, 700.0),
#  (800.0, 800.0),
#  (800.0, 900.0),
#  (800.0, 1000.0),
#  (900.0, 100.0),
#  (900.0, 200.0),
#  (900.0, 300.0),
#  (900.0, 400.0),
#  (900.0, 500.0),
#  (900.0, 600.0),
#  (900.0, 700.0),
#  (900.0, 800.0),
#  (900.0, 900.0),
#  (900.0, 1000.0),
#  (1000.0, 100.0),
#  (1000.0, 200.0),
#  (1000.0, 300.0),
#  (1000.0, 400.0),
#  (1000.0, 500.0),
#  (1000.0, 600.0),
#  (1000.0, 700.0),
#  (1000.0, 800.0),
#  (1000.0, 900.0),
#  (1000.0, 1000.0)]

# %%
for hparam in tqdm(combinations):
    out = apriori_NB(train=train, test=test, method=method, hparams=hparam)
    #f1, acc = out
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Performance: f1=0.7031  |  acc=0.8907
#    sets=[100, 100]: [100,100]
#
# Performance: f1=0.73273  |  acc=0.90321
#    sets=[100, 200]: [100,200]
#
# Performance: f1=0.74242  |  acc=0.90756
#    sets=[100, 300]: [100,300]
#
# Performance: f1=0.74085  |  acc=0.90756
#    sets=[100, 400]: [100,400]
#
# Performance: f1=0.73574  |  acc=0.9043
#    sets=[100, 500]: [100,500]
#
# Performance: f1=0.73134  |  acc=0.90212
#    sets=[100, 600]: [100,600]
#
# Performance: f1=0.73134  |  acc=0.90212
#    sets=[100, 700]: [100,700]
#
# Performance: f1=0.73134  |  acc=0.90212
#    sets=[100, 800]: [100,800]
#
# Performance: f1=0.73134  |  acc=0.90212
#    sets=[100, 900]: [100,900]
#
# Performance: f1=0.72059  |  acc=0.89668
#    sets=[100, 1000]: [100,1000]
#
# Performance: f1=0.65569  |  acc=0.86351
#    sets=[200, 100]: [200,100]
#
# Performance: f1=0.73314  |  acc=0.90103
#    sets=[200, 200]: [200,200]
#
# Performance: f1=0.74363  |  acc=0.90701
#    sets=[200, 300]: [200,300]
#
# Performance: f1=0.74735  |  acc=0.90919
#    sets=[200, 400]: [200,400]
#
# Performance: f1=0.74328  |  acc=0.90647
#    sets=[200, 500]: [200,500]
#
# Performance: f1=0.74398  |  acc=0.90756
#    sets=[200, 600]: [200,600]
#
# Performance: f1=0.74286  |  acc=0.90701
#    sets=[200, 700]: [200,700]
#
# Performance: f1=0.74286  |  acc=0.90701
#    sets=[200, 800]: [200,800]
#
# Performance: f1=0.74286  |  acc=0.90701
#    sets=[200, 900]: [200,900]
#
# Performance: f1=0.72621  |  acc=0.89831
#    sets=[200, 1000]: [200,1000]
#
# Performance: f1=0.58164  |  acc=0.80914
#    sets=[300, 100]: [300,100]
#
# Performance: f1=0.70014  |  acc=0.88309
#    sets=[300, 200]: [300,200]
#
# Performance: f1=0.73285  |  acc=0.90049
#    sets=[300, 300]: [300,300]
#
# Performance: f1=0.7426  |  acc=0.90538
#    sets=[300, 400]: [300,400]
#
# Performance: f1=0.73256  |  acc=0.89995
#    sets=[300, 500]: [300,500]
#
# Performance: f1=0.74251  |  acc=0.90647
#    sets=[300, 600]: [300,600]
#
# Performance: f1=0.74141  |  acc=0.90593
#    sets=[300, 700]: [300,700]
#
# Performance: f1=0.74141  |  acc=0.90593
#    sets=[300, 800]: [300,800]
#
# Performance: f1=0.74141  |  acc=0.90593
#    sets=[300, 900]: [300,900]
#
# Performance: f1=0.71965  |  acc=0.89451
#    sets=[300, 1000]: [300,1000]
#
# Performance: f1=0.49899  |  acc=0.73029
#    sets=[400, 100]: [400,100]
#
# Performance: f1=0.63317  |  acc=0.84122
#    sets=[400, 200]: [400,200]
#
# Performance: f1=0.68759  |  acc=0.87548
#    sets=[400, 300]: [400,300]
#
# Performance: f1=0.70886  |  acc=0.88744
#    sets=[400, 400]: [400,400]
#
# Performance: f1=0.69806  |  acc=0.88146
#    sets=[400, 500]: [400,500]
#
# Performance: f1=0.72938  |  acc=0.89831
#    sets=[400, 600]: [400,600]
#
# Performance: f1=0.72727  |  acc=0.89723
#    sets=[400, 700]: [400,700]
#
# Performance: f1=0.72727  |  acc=0.89723
#    sets=[400, 800]: [400,800]
#
# Performance: f1=0.72727  |  acc=0.89723
#    sets=[400, 900]: [400,900]
#
# Performance: f1=0.70376  |  acc=0.88418
#    sets=[400, 1000]: [400,1000]
#
# Performance: f1=0.43739  |  acc=0.65307
#    sets=[500, 100]: [500,100]
#
# Performance: f1=0.56629  |  acc=0.7901
#    sets=[500, 200]: [500,200]
#
# Performance: f1=0.63797  |  acc=0.84448
#    sets=[500, 300]: [500,300]
#
# Performance: f1=0.6702  |  acc=0.8646
#    sets=[500, 400]: [500,400]
#
# Performance: f1=0.65971  |  acc=0.85808
#    sets=[500, 500]: [500,500]
#
# Performance: f1=0.68852  |  acc=0.87602
#    sets=[500, 600]: [500,600]
#
# Performance: f1=0.68759  |  acc=0.87548
#    sets=[500, 700]: [500,700]
#
# Performance: f1=0.68759  |  acc=0.87548
#    sets=[500, 800]: [500,800]
#
# Performance: f1=0.68759  |  acc=0.87548
#    sets=[500, 900]: [500,900]
#
# Performance: f1=0.66931  |  acc=0.86406
#    sets=[500, 1000]: [500,1000]
#
# Performance: f1=0.40292  |  acc=0.60033
#    sets=[600, 100]: [600,100]
#
# Performance: f1=0.51318  |  acc=0.73899
#    sets=[600, 200]: [600,200]
#
# Performance: f1=0.58565  |  acc=0.80533
#    sets=[600, 300]: [600,300]
#
# Performance: f1=0.62765  |  acc=0.83741
#    sets=[600, 400]: [600,400]
#
# Performance: f1=0.6201  |  acc=0.83143
#    sets=[600, 500]: [600,500]
#
# Performance: f1=0.65885  |  acc=0.85753
#    sets=[600, 600]: [600,600]
#
# Performance: f1=0.65714  |  acc=0.85644
#    sets=[600, 700]: [600,700]
#
# Performance: f1=0.65714  |  acc=0.85644
#    sets=[600, 800]: [600,800]
#
# Performance: f1=0.65714  |  acc=0.85644
#    sets=[600, 900]: [600,900]
#
# Performance: f1=0.64223  |  acc=0.84611
#    sets=[600, 1000]: [600,1000]
#
# Performance: f1=0.37871  |  acc=0.55574
#    sets=[700, 100]: [700,100]
#
# Performance: f1=0.47798  |  acc=0.69712
#    sets=[700, 200]: [700,200]
#
# Performance: f1=0.5524  |  acc=0.77705
#    sets=[700, 300]: [700,300]
#
# Performance: f1=0.59645  |  acc=0.81457
#    sets=[700, 400]: [700,400]
#
# Performance: f1=0.58565  |  acc=0.80533
#    sets=[700, 500]: [700,500]
#
# Performance: f1=0.63648  |  acc=0.84285
#    sets=[700, 600]: [700,600]
#
# Performance: f1=0.63568  |  acc=0.84231
#    sets=[700, 700]: [700,700]
#
# Performance: f1=0.63568  |  acc=0.84231
#    sets=[700, 800]: [700,800]
#
# Performance: f1=0.63568  |  acc=0.84231
#    sets=[700, 900]: [700,900]
#
# Performance: f1=0.61725  |  acc=0.82871
#    sets=[700, 1000]: [700,1000]
#
# Performance: f1=0.36311  |  acc=0.52311
#    sets=[800, 100]: [800,100]
#
# Performance: f1=0.44952  |  acc=0.65905
#    sets=[800, 200]: [800,200]
#
# Performance: f1=0.51371  |  acc=0.73953
#    sets=[800, 300]: [800,300]
#
# Performance: f1=0.55973  |  acc=0.78358
#    sets=[800, 400]: [800,400]
#
# Performance: f1=0.54409  |  acc=0.76944
#    sets=[800, 500]: [800,500]
#
# Performance: f1=0.59882  |  acc=0.81566
#    sets=[800, 600]: [800,600]
#
# Performance: f1=0.59811  |  acc=0.81512
#    sets=[800, 700]: [800,700]
#
# Performance: f1=0.59811  |  acc=0.81512
#    sets=[800, 800]: [800,800]
#
# Performance: f1=0.59811  |  acc=0.81512
#    sets=[800, 900]: [800,900]
#
# Performance: f1=0.58324  |  acc=0.80261
#    sets=[800, 1000]: [800,1000]
#
# Performance: f1=0.35861  |  acc=0.50788
#    sets=[900, 100]: [900,100]
#
# Performance: f1=0.43649  |  acc=0.64057
#    sets=[900, 200]: [900,200]
#
# Performance: f1=0.49414  |  acc=0.71833
#    sets=[900, 300]: [900,300]
#
# Performance: f1=0.53207  |  acc=0.75802
#    sets=[900, 400]: [900,400]
#
# Performance: f1=0.52058  |  acc=0.7466
#    sets=[900, 500]: [900,500]
#
# Performance: f1=0.5724  |  acc=0.79445
#    sets=[900, 600]: [900,600]
#
# Performance: f1=0.5724  |  acc=0.79445
#    sets=[900, 700]: [900,700]
#
# Performance: f1=0.5724  |  acc=0.79445
#    sets=[900, 800]: [900,800]
#
# Performance: f1=0.5724  |  acc=0.79445
#    sets=[900, 900]: [900,900]
#
# Performance: f1=0.55947  |  acc=0.78249
#    sets=[900, 1000]: [900,1000]
#
# Performance: f1=0.34328  |  acc=0.47363
#    sets=[1000, 100]: [1000,100]
#
# Performance: f1=0.41424  |  acc=0.60631
#    sets=[1000, 200]: [1000,200]
#
# Performance: f1=0.47026  |  acc=0.69005
#    sets=[1000, 300]: [1000,300]
#
# Performance: f1=0.5  |  acc=0.72376
#    sets=[1000, 400]: [1000,400]
#
# Performance: f1=0.4894  |  acc=0.7118
#    sets=[1000, 500]: [1000,500]
#
# Performance: f1=0.53586  |  acc=0.76074
#    sets=[1000, 600]: [1000,600]
#
# Performance: f1=0.53586  |  acc=0.76074
#    sets=[1000, 700]: [1000,700]
#
# Performance: f1=0.53586  |  acc=0.76074
#    sets=[1000, 800]: [1000,800]
#
# Performance: f1=0.53586  |  acc=0.76074
#    sets=[1000, 900]: [1000,900]
#
# Performance: f1=0.52415  |  acc=0.74823
#    sets=[1000, 1000]: [1000,1000]

# %%
sum(train.label=='ham')/len(train)
# Out:
# 0.8698098044468257

# %%
# testing 
start_time = time.time()
out = apriori_NB(train=train, test=test, method=method, hparams=(3000, 1000))
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/p0/2qnwrmjn7yd0ks7pnlb3d7mc0000gn/T/ipykernel_55088/447128650.py in <module>
#       1 # testing
#       2 start_time = time.time()
# ----> 3 out = apriori_NB(train=train, test=test, method=method, hparams=(3000, 1000))
#       4 print("--- %s seconds ---" % (time.time() - start_time))
#       5
#
# /var/folders/p0/2qnwrmjn7yd0ks7pnlb3d7mc0000gn/T/ipykernel_55088/1239821054.py in apriori_NB(train, test, method, hparams)
#     141
#     142     # getting frequent itemsets
# --> 143     freq_itemsets_dict = get_freq_itemset(train, labels, look_up, num_itemsets)
#     144     # word_freq_dict =  apriori_for_binary(train, labels, minimum_support, look_up)
#     145
#
# /var/folders/p0/2qnwrmjn7yd0ks7pnlb3d7mc0000gn/T/ipykernel_55088/1239821054.py in get_freq_itemset(data, labels, look_up, num_itemsets)
#      52             te_ary = te.fit(look_up_data).transform(look_up_data)
#      53             df = pd.DataFrame(te_ary, columns=te.columns_)
# ---> 54             itemsets = apriori(df, min_support=support, use_colnames=True)
#      55             support -= support/20
#      56         # finding top supported
#
# ~/opt/anaconda3/envs/comsocsci2022/lib/python3.8/site-packages/mlxtend/frequent_patterns/apriori.py in apriori(df, min_support, use_colnames, max_len, verbose, low_memory)
#     309                 _bools = np.all(X[:, combin], axis=2)
#     310
# --> 311             support = _support(np.array(_bools), rows_count, is_sparse)
#     312             _mask = (support >= min_support).reshape(-1)
#     313             if any(_mask):
#
# ~/opt/anaconda3/envs/comsocsci2022/lib/python3.8/site-packages/mlxtend/frequent_patterns/apriori.py in _support(_x, _n_rows, _is_sparse)
#     229
#     230         """
# --> 231         out = np.sum(_x, axis=0) / _n_rows
#     232         return np.array(out).reshape(-1)
#     233
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# ~/opt/anaconda3/envs/comsocsci2022/lib/python3.8/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2257         return res
#    2258
# -> 2259     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2260                           initial=initial, where=where)
#    2261
#
# ~/opt/anaconda3/envs/comsocsci2022/lib/python3.8/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# KeyboardInterrupt:

# %% [markdown]
# # Discussion
#
#
# - minimum is hard to tweak for each new dataset (chose num in freq instead)
# - support varies per freq itemset, normalize with the denominator
# - the ham might contain typical stopwords, somethings represented in both
# - not good with imblanced datasets?
# - we add min(y)/2: https://towardsdatascience.com/laplace-smoothing-in-naïve-bayes-algorithm-9c237a8bdece
# -

# %% [markdown]
# ---
#
# # Pilot for the _ dataset

# %% [markdown]
# ### Shingles

# %% [markdown]
# ### Terms
